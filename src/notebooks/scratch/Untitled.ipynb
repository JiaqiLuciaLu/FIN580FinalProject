# %%
import pandas as pd

# %%
pd.read_csv('/scratch/network/jl6134/COLLAB/FIN580/FIN580FinalProject/plots/table1/table1_comparison.csv')
# Out:
#            metric       AP10_ours    AP10_paper       AP40_ours    AP40_paper  \
# 0          SDF SR           0.637          0.65           0.669          0.69
# 1       alpha_FF3  3.186 [10.334]  0.94 [10.11]  5.862 [10.866]  0.90 [11.03]
# 2       alpha_FF5   3.191 [9.969]   0.81 [8.76]  5.920 [10.695]   0.76 [9.60]
# 3       alpha_XSF  3.310 [10.350]   0.81 [8.77]  6.228 [11.215]   0.76 [9.46]
# 4      alpha_FF11   3.230 [9.501]   0.89 [9.12]  6.044 [10.314]   0.80 [9.60]
# 5   xs_r2_adj_FF3         -0.5552          0.18          0.0267          0.51
# 6   xs_r2_adj_FF5         -1.0783          0.11          0.1253          0.64
# 7   xs_r2_adj_XSF         -0.6181          0.28          0.1890          0.65
# 8  xs_r2_adj_FF11             NaN           NaN         -0.4429          0.42
#
#        TS32_ours   TS32_paper      TS64_ours   TS64_paper
# 0          0.522         0.51          0.567         0.53
# 1  3.527 [8.026]  0.75 [7.40]  3.547 [9.039]  0.84 [8.13]
# ...
